# %% [markdown]
# <a href="https://colab.research.google.com/github/25WH1A0524/NASSCOM-LAB/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")

name = "Maxie"
age = 18
height = 5.7

print("Name:", name)
print("Age:", age)
print("Height:", height)

name = 6767
print("New value of name:", name)

a = 20
print(type(a))
b = 3.14
print(type(b))
c = "Python"
print(type(c))
d = False
print(type(d))
e = [1, 2, 3, 4, "five"]
print(type(e), e)
f = {"name": "Maxie", "age": 18}
print(type(f), f)

print("Welcome to Python I/O!")

user_name = input("Enter your name: ")
print("Hello,", user_name)

user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Hello, Python!
# This is indented correctly.
# Name: Maxie
# Age: 18
# Height: 5.7
# New value of name: 6767
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 4, 'five']
# <class 'dict'> {'name': 'Maxie', 'age': 18}
# Welcome to Python I/O!
# Enter your name: MAXIE
# Hello, MAXIE
# Enter your age: 67
# You will be 68 next year.
