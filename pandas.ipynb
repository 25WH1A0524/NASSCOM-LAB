# %% [markdown]
# <a href="https://colab.research.google.com/github/25WH1A0524/NASSCOM-LAB/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print("\nSeries:")
print(s)
data = {
    'Name': ['blair', 'max', 'maxie', 'emily'],
    'Age': [22, 24, 25, 30],
    'Salary': [500000, 600000, 700000, 800000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)

array = np.array([[10, 20], [30, 40], [50, 60]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)

print("\nRow with label 1 using loc:")
print(df.loc[1])

print("\nFirst two rows using iloc:")
print(df.iloc[0:2])

print("\nSelect 'Name' column:")
print(df['Name'])
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])
print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 60000])

data_dirty = {
    'Name': ['blair', 'max', None, 'emily'],
    'Age': [22, None, 25, 30],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)

print("\nDrop rows with any NaN values:")
print(df_dirty.dropna())
print("\nFill missing values with a specific value:")
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))

print("\nBoolean DataFrame for missing values:")
print(df_dirty.isnull())

df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df)
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())

print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)

print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))
print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())

np.random.seed(1)
num_rows = 11
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})

print("\nSynthetic DataFrame:")
print(df_synth)

print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())

print("\nDataFrame info:")
df.info()
print("\nDataFrame describe:")
print(df.describe())

print("\nDataFrame info:")
df.info()
print("\nDataFrame describe:")
print(df.describe())

print("\nData types of each column:")
print(df.dtypes)
print("\nFirst 3 rows:")
print(df.head(3))
print("\nLast 2 rows:")
print(df.tail(2))

print("\nMean Age:", df['Age'].mean())
print("Median Salary:", df['Salary'].median())
print("Mode of Bonus:")
print(df['Bonus'].mode())
print("Standard Deviation of Salary:", df['Salary'].std())
print("Variance of Salary:", df['Salary'].var())

print("\nCorrelation between Age and Salary:")
print(df[['Age', 'Salary']].corr())
print("\nCovariance between Age and Salary:")
print(df[['Age', 'Salary']].cov())
print("\nValue counts for AgeGroup:")
print(df['AgeGroup'].value_counts())

print("\nCumulative sum of Salary:")
print(df['Salary'].cumsum())
print("\nCumulative max of Salary:")
print(df['Salary'].cummax())
print("\nRank of Salary:")
print(df['Salary'].rank())
print("\nQuantiles of Salary:")
print(df['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Series:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# DataFrame:
#     Name  Age  Salary
# 0  blair   22  500000
# 1    max   24  600000
# 2  maxie   25  700000
# 3  emily   30  800000
#
# DataFrame from NumPy array:
#    Column1  Column2
# 0       10       20
# 1       30       40
# 2       50       60
#
# Row with label 1 using loc:
# Name         max
# Age           24
# Salary    600000
# Name: 1, dtype: object
#
# First two rows using iloc:
#     Name  Age  Salary
# 0  blair   22  500000
# 1    max   24  600000
#
# Select 'Name' column:
# 0    blair
# 1      max
# 2    maxie
# 3    emily
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#     Name  Age
# 0  blair   22
# 1    max   24
# 2  maxie   25
# 3  emily   30
#
# Rows where Salary > 60000:
#     Name  Age  Salary
# 0  blair   22  500000
# 1    max   24  600000
# 2  maxie   25  700000
# 3  emily   30  800000
#
# Original Dirty DataFrame:
#     Name   Age   Salary
# 0  blair  22.0  50000.0
# 1    max   NaN  60000.0
# 2   None  25.0      NaN
# 3  emily  30.0  80000.0
#
# Drop rows with any NaN values:
#     Name   Age   Salary
# 0  blair  22.0  50000.0
# 3  emily  30.0  80000.0
#
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0    blair  22.000000  50000.0
# 1      max  25.666667  60000.0
# 2  Unknown  25.000000      0.0
# 3    emily  30.000000  80000.0
#
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False
#
# DataFrame with Bonus column:
#     Name  Age  Salary    Bonus
# 0  blair   22  500000  50000.0
# 1    max   24  600000  60000.0
# 2  maxie   25  700000  70000.0
# 3  emily   30  800000  80000.0
#
# Rename columns:
#     Name  Age  BaseSalary    Bonus
# 0  blair   22      500000  50000.0
# 1    max   24      600000  60000.0
# 2  maxie   25      700000  70000.0
# 3  emily   30      800000  80000.0
#
# Sort by Age descending:
#     Name  Age  Salary    Bonus
# 3  emily   30  800000  80000.0
# 2  maxie   25  700000  70000.0
# 1    max   24  600000  60000.0
# 0  blair   22  500000  50000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    650000.0
# Name: Salary, dtype: float64
#
# Rename columns:
#     Name  Age  BaseSalary    Bonus  AgeGroup
# 0  blair   22      500000  50000.0     False
# 1    max   24      600000  60000.0     False
# 2  maxie   25      700000  70000.0     False
# 3  emily   30      800000  80000.0     False
#
# Sort by Age descending:
#     Name  Age  Salary    Bonus  AgeGroup
# 3  emily   30  800000  80000.0     False
# 2  maxie   25  700000  70000.0     False
# 1    max   24  600000  60000.0     False
# 0  blair   22  500000  50000.0     False
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    650000.0
# Name: Salary, dtype: float64
#
# Synthetic DataFrame:
#     ID  Score  Passed
# 0    1     87    True
# 1    2     93   False
# 2    3     62   False
# 3    4     58    True
# 4    5     59    True
# 5    6     61   False
# 6    7     55    True
# 7    8     65    True
# 8    9     50    True
# 9   10     66   False
# 10  11     51    True
#
# Students who passed:
#     ID  Score  Passed
# 0    1     87    True
# 3    4     58    True
# 4    5     59    True
# 6    7     55    True
# 7    8     65    True
# 8    9     50    True
# 10  11     51    True
#
# Average score of failed students:
# 70.5
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   Salary    4 non-null      int64
#  3   Bonus     4 non-null      float64
#  4   AgeGroup  4 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 264.0+ bytes
#
# DataFrame describe:
#             Age         Salary         Bonus
# count   4.00000       4.000000      4.000000
# mean   25.25000  650000.000000  65000.000000
# std     3.40343  129099.444874  12909.944487
# min    22.00000  500000.000000  50000.000000
# 25%    23.50000  575000.000000  57500.000000
# 50%    24.50000  650000.000000  65000.000000
# 75%    26.25000  725000.000000  72500.000000
# max    30.00000  800000.000000  80000.000000
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   Salary    4 non-null      int64
#  3   Bonus     4 non-null      float64
#  4   AgeGroup  4 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 264.0+ bytes
#
# DataFrame describe:
#             Age         Salary         Bonus
# count   4.00000       4.000000      4.000000
# mean   25.25000  650000.000000  65000.000000
# std     3.40343  129099.444874  12909.944487
# min    22.00000  500000.000000  50000.000000
# 25%    23.50000  575000.000000  57500.000000
# 50%    24.50000  650000.000000  65000.000000
# 75%    26.25000  725000.000000  72500.000000
# max    30.00000  800000.000000  80000.000000
#
# Data types of each column:
# Name         object
# Age           int64
# Salary        int64
# Bonus       float64
# AgeGroup       bool
# dtype: object
#
# First 3 rows:
#     Name  Age  Salary    Bonus  AgeGroup
# 0  blair   22  500000  50000.0     False
# 1    max   24  600000  60000.0     False
# 2  maxie   25  700000  70000.0     False
#
# Last 2 rows:
#     Name  Age  Salary    Bonus  AgeGroup
# 2  maxie   25  700000  70000.0     False
# 3  emily   30  800000  80000.0     False
#
# Mean Age: 25.25
# Median Salary: 650000.0
# Mode of Bonus:
# 0    50000.0
# 1    60000.0
# 2    70000.0
# 3    80000.0
# Name: Bonus, dtype: float64
# Standard Deviation of Salary: 129099.44487358056
# Variance of Salary: 16666666666.666666
#
# Correlation between Age and Salary:
#              Age    Salary
# Age     1.000000  0.948304
# Salary  0.948304  1.000000
#
# Covariance between Age and Salary:
#                   Age        Salary
# Age         11.583333  4.166667e+05
# Salary  416666.666667  1.666667e+10
#
# Value counts for AgeGroup:
# AgeGroup
# False    4
# Name: count, dtype: int64
#
# Cumulative sum of Salary:
# 0     500000
# 1    1100000
# 2    1800000
# 3    2600000
# Name: Salary, dtype: int64
#
# Cumulative max of Salary:
# 0    500000
# 1    600000
# 2    700000
# 3    800000
# Name: Salary, dtype: int64
#
# Rank of Salary:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    575000.0
# 0.50    650000.0
# 0.75    725000.0
# Name: Salary, dtype: float64
