# %% [markdown]
# <a href="https://colab.research.google.com/github/25WH1A0524/NASSCOM-LAB/blob/main/Working_with_Core_Python_Libraries_OS_%2C_datetime_%2C_random_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())

os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")

from datetime import datetime, date, timedelta
now = datetime.now()
print("Now:", now)

today = date.today()
print("Today's Date:", today)

dob = date(2026, 7, 19)
print("DOB:", dob)

yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)

formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)

import random
print("Random Int:", random.randint(1, 100))
print("Random Float:", random.random())

colors = ['black', 'white', 'pink']
print("Random Color:", random.choice(colors))

random.shuffle(colors)
print("Shuffled List:", colors)

print("Sample:", random.sample(range(1, 50), 5))


from collections import Counter

fruits = ['pineapple', 'banana', 'pineapple', 'orange', 'banana', 'pineapple']
count = Counter(fruits)
print("Fruit Count:", count)

from collections import defaultdict
marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 67
print("English Marks (not set):", marks['English'])

from collections import namedtuple

Point = namedtuple('Point', 'x y')
p1 = Point(100, 200)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)

from collections import deque

dq = deque([1, 2, 3])
dq.append(4)
dq.appendleft(0)
dq.pop()
dq.popleft()
print("Deque after operations:", dq)
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']
# Now: 2026-07-19 13:34:08.291585
# Today's Date: 2026-07-19
# DOB: 2026-07-19
# Yesterday: 2026-07-18
# Tomorrow: 2026-07-20
# Formatted DateTime: 19-07-2026 13:34:08
# Random Int: 99
# Random Float: 0.4948829335642362
# Random Color: white
# Shuffled List: ['white', 'pink', 'black']
# Sample: [3, 11, 9, 40, 20]
# Fruit Count: Counter({'pineapple': 3, 'banana': 2, 'orange': 1})
# English Marks (not set): 0
# Point: Point(x=100, y=200)
# x: 100 y: 200
# Deque after operations: deque([1, 2, 3])
